# %%
using Plots
using ParticleFilters
using Distributions
using StaticArrays
using LinearAlgebra
using Random
using StatsBase
#using Reel
using SparseArrays
using GridInterpolations
using DataStructures
using DataFrames
using CSV
using Distributed

# %%
include("atan2.jl")
include("obs_rel.jl")
include("polargrid_rel_qual.jl")
rng = MersenneTwister(2);
#

# %%
# random walk

POS_0 = [6.0, 60.0]
CRS_0 = 90 # target's course
SPD_0 = 1 # 1 or 2
TGT_SPD = 1

#input is course in degrees and rng
#returns next course in degrees
function next_crs(crs,rng)
    if rand(rng) < .9
        return crs
    end
    crs = (crs + rand(rng,[-1,1])*30) % 360
    if crs < 0 crs += 360 end
    return crs
end

# state as tuple (x, y, crs, spd) of target (spd of o/s)
function f(state, control, rng)
    r, θ, crs, spd = state
    θ += control[1]
    spd = control[2]
    if θ < 0 θ += 360 end
    θ = θ % 360
    crs -= control[1]
    if crs < 0 crs += 360 end
    crs = crs % 360
    x = r*cos(π/180*θ)
    y = r*sin(π/180*θ)
    pos = [x + TGT_SPD*cos(π/180*crs) - spd, y + 
        TGT_SPD*sin(π/180*crs)]
    crs = next_crs(crs,rng)
    r = sqrt(pos[1]^2 + pos[2]^2)
    θ = atan2(pos[1],pos[2])*180/π
    if θ < 0 θ += 360 end
    return (r, θ, crs, spd)::NTuple{4, Real}
end
#
# Out:
# f (generic function with 1 method)

# %%
function r(s)
    range = s[1]
    if range > 150 return -.1 end  # reward to not lose track of contact
    if range <= 10 return -1 end  # collision avoidance
    return .1  # being in "sweet spot" maximizes reward
end
#
# Out:
# r (generic function with 1 method)

# %%
#angles = [0, 30, 60, 90, 120, 150, 210, 240, 270, 300, 330]

statespace = thestates
actionspace = ((30,1), (0,1), (-30,1), (30, 2), (0,2), (-30,2))

action_index(a) = trunc(Int, 2*(a[1]/30+1) + a[2])
actions_ = ((-30,1), (-30, 2), (0, 1), (0, 2), (30, 1), (30, 2))
# Out:
# ((-30, 1), (-30, 2), (0, 1), (0, 2), (30, 1), (30, 2))

# %%
# returns vector rather than Tuple, for particle filter
function f2(x, u, rng)
    temp = [i for i in f(x, u, rng)]
    return temp
end
# Out:
# f2 (generic function with 1 method)

# %%
totals = [0.0]
θ = zeros(length(grid),6);
e = sparse(zeros(length(grid),6))
#θ = [r(Tuple(ind2x(grid, j))) for j in 1:length(grid), i in 1:6];

# %%
N = 500
model = ParticleFilterModel{Vector{Float64}}(f2, g)
pfilter = SIRParticleFilter(model, N);
α = 0.5
γ = 0.98
ϵ = 0.15
x = [20, 60, 90, 1, 1];
λ = 0.95
b = ParticleCollection([[20, 60, 90, 1] for i in 1:N]);
counter = 0
# Out:
# 0

# %%
## Q-learning loop
#plots = []
#betas = Deque{Array}()
#β = zeros(length(grid),6);

epochs = 5000
epochsize = 500

total = 0
rando = 0

last = 0
x = [rand(rng, 25:150), rand(rng,0:359), rand(rng,0:11)*30, 1, 1];     
b = ParticleCollection([x[1:4] for i in 1:N]);     
ξ = sparse(weighted_grid_2(b)/N)
uu = next_action([transpose(θ[:,j])*ξ for j in 1:size(θ)[2]], ϵ, rng)
u = uu[1]
rando += uu[2]

for i in 1:(epochsize*epochs)
    counter += 1
    
    e[:,u] += ξ
    last = transpose(θ[:,u])*ξ
    
    # choose next action
    uu = next_action([transpose(θ[:,j])*ξ for j in 1:size(θ)[2]], ϵ, rng)
    u = uu[1]
    rando += uu[2]
    a_star = uu[3]
    
    #observe new state and reward
    xp = f2(x, actions_[u], rng)
    y = h(xp, rng)
    b = update(pfilter, b, actions_[u], y)
    rew = r(Tuple(xp))
       
    ξ = sparse(weighted_grid_2(b)/N)
     
    total += rew
        
    #cur = (rew + γ * max2([transpose(θ[:,j])*ξ for j in 1:size(θ)[2]], rng))
    
    #argmax state-action pair, not realized state-action pair?
    cur = transpose(θ[:,a_star])*ξ
    
    δ = rew + γ * cur - last
    
    θ += α * δ * e
    #if uu[2] == 0
    e *= γ * λ
    #else
    #    e = sparse(zeros(length(grid),6))
    #end
    
        
    if counter % epochsize == 0
        push!(totals, total*500/epochsize)
        println("--------- CURRENT: ", round(total*500/epochsize, sigdigits=4), " AVG: ", round(mean(totals), sigdigits=4), " Epoch: ", 
            trunc(Int, counter/epochsize), " -----------")
        total = 0
        rando = 0
        xp = [rand(rng, 25:150), rand(rng,0:359), rand(rng,0:11)*30, rand(rng, [1,2]), 1];
        b = ParticleCollection([xp[1:4] for i in 1:N]);
        ξ = sparse(weighted_grid_2(b)/N)
    end
    if counter % (epochsize*5) == 0
        thetaframe = DataFrame(θ)
        CSV.write("current4_2.csv", thetaframe)
    end
    
    x = xp
    
    
    #plotting
    #r_ = [row[1] for row in particles(b)]
    #theta = [row[2] for row in particles(b)]*π/180
    #x_theta = x[2]*π/180
    #x_r = x[1 ]
    
    #print(".")
    #plt = plot(proj=:polar, lims=(0,200), size=(1000,1000))
    #scatter!(theta, r_, markersize=1, label="particles")
    #scatter!([x_theta], [x_r], markersize=3, label="target")
          
    #push!(plots, plt)
    
end
# Out:
# --------- CURRENT: 9.3 AVG: 8.819 Epoch: 7737 -----------
# --------- CURRENT: 29.1 AVG: 8.821 Epoch: 7738 -----------
# --------- CURRENT: 31.3 AVG: 8.824 Epoch: 7739 -----------
# --------- CURRENT: 26.8 AVG: 8.826 Epoch: 7740 -----------
# --------- CURRENT: 29.6 AVG: 8.828 Epoch: 7741 -----------
# --------- CURRENT: 23.8 AVG: 8.829 Epoch: 7742 -----------
# --------- CURRENT: 29.4 AVG: 8.831 Epoch: 7743 -----------
# --------- CURRENT: -41.0 AVG: 8.826 Epoch: 7744 -----------
# --------- CURRENT: 37.8 AVG: 8.829 Epoch: 7745 -----------
# --------- CURRENT: 39.6 AVG: 8.832 Epoch: 7746 -----------
# --------- CURRENT: 50.0 AVG: 8.836 Epoch: 7747 -----------
# --------- CURRENT: 30.9 AVG: 8.839 Epoch: 7748 -----------
# --------- CURRENT: -16.8 AVG: 8.836 Epoch: 7749 -----------
# --------- CURRENT: 39.0 AVG: 8.839 Epoch: 7750 -----------
# --------- CURRENT: 21.3 AVG: 8.84 Epoch: 7751 -----------
# --------- CURRENT: -47.8 AVG: 8.835 Epoch: 7752 -----------
# --------- CURRENT: 37.6 AVG: 8.837 Epoch: 7753 -----------
# --------- CURRENT: 42.6 AVG: 8.841 Epoch: 7754 -----------
# --------- CURRENT: 49.6 AVG: 8.845 Epoch: 7755 -----------
# --------- CURRENT: 8.2 AVG: 8.845 Epoch: 7756 -----------
# --------- CURRENT: -25.0 AVG: 8.842 Epoch: 7757 -----------
# --------- CURRENT: 50.0 AVG: 8.846 Epoch: 7758 -----------
# --------- CURRENT: 35.7 AVG: 8.848 Epoch: 7759 -----------
# --------- CURRENT: 5.6 AVG: 8.848 Epoch: 7760 -----------
# --------- CURRENT: -32.0 AVG: 8.844 Epoch: 7761 -----------
# --------- CURRENT: -45.8 AVG: 8.838 Epoch: 7762 -----------
# --------- CURRENT: 45.8 AVG: 8.842 Epoch: 7763 -----------
# --------- CURRENT: -2.2 AVG: 8.841 Epoch: 7764 -----------
# --------- CURRENT: -21.6 AVG: 8.838 Epoch: 7765 -----------
# --------- CURRENT: 16.8 AVG: 8.839 Epoch: 7766 -----------
# --------- CURRENT: 50.0 AVG: 8.843 Epoch: 7767 -----------
# --------- CURRENT: 46.0 AVG: 8.847 Epoch: 7768 -----------
# --------- CURRENT: -25.4 AVG: 8.843 Epoch: 7769 -----------
# --------- CURRENT: 50.0 AVG: 8.847 Epoch: 7770 -----------
# --------- CURRENT: 14.8 AVG: 8.848 Epoch: 7771 -----------
# --------- CURRENT: 39.1 AVG: 8.851 Epoch: 7772 -----------
# --------- CURRENT: 50.0 AVG: 8.855 Epoch: 7773 -----------
# --------- CURRENT: -40.6 AVG: 8.85 Epoch: 7774 -----------
# --------- CURRENT: 50.0 AVG: 8.854 Epoch: 7775 -----------
# --------- CURRENT: -61.4 AVG: 8.847 Epoch: 7776 -----------
# --------- CURRENT: 50.0 AVG: 8.851 Epoch: 7777 -----------
# --------- CURRENT: -35.4 AVG: 8.847 Epoch: 7778 -----------
# --------- CURRENT: -25.0 AVG: 8.844 Epoch: 7779 -----------
# --------- CURRENT: -20.0 AVG: 8.841 Epoch: 7780 -----------
# --------- CURRENT: 32.0 AVG: 8.843 Epoch: 7781 -----------
# --------- CURRENT:

# %%
transpose(θ[:,2])*ξ
# Out:
# 0.0015269765963268022

# %%
xx = []
yy = []
yyy = []
for (i, t) in enumerate(totals)
    push!(xx, i)
    push!(yy, t)
    push!(yyy, mean(yy))
end

plot(xx, yyy, ylims = (0,50))

# %%
# Out:
# 2.0131182926706272e35

# %%
thetaframe = DataFrame(θ)
CSV.write("0.44_theta_12.1_1.csv", thetaframe)
# Out:
# "0.44_theta_12.1_1.csv"

# %%
b = ParticleCollection([[20, 60, 90, 1] for i in 1:N]);
ξ = weighted_grid_2(b)/N
var(ξ)
# Out:
# 3.5612535612535624e-5
