# %%
using Plots
using ParticleFilters
using Distributions
using StaticArrays
using LinearAlgebra
using Random
using StatsBase
#using Reel
using SparseArrays
using GridInterpolations
using DataStructures
using DataFrames
using CSV
using Distributed

# %%
include("atan2.jl")
include("obs_rel.jl")
include("polargrid_rel_qual.jl")
rng = MersenneTwister(2);
#

# %%
# random walk

POS_0 = [6.0, 60.0]
CRS_0 = 90 # target's course
SPD_0 = 1 # 1 or 2
TGT_SPD = 1

#input is course in degrees and rng
#returns next course in degrees
function next_crs(crs,rng)
    if rand(rng) < .9
        return crs
    end
    crs = (crs + rand(rng,[-1,1])*30) % 360
    if crs < 0 crs += 360 end
    return crs
end

# state as tuple (x, y, crs, spd) of target (spd of o/s)
function f(state, control, rng)
    r, θ, crs, spd = state
    θ += control[1]
    spd = control[2]
    if θ < 0 θ += 360 end
    θ = θ % 360
    crs -= control[1]
    if crs < 0 crs += 360 end
    crs = crs % 360
    x = r*cos(π/180*θ)
    y = r*sin(π/180*θ)
    pos = [x + TGT_SPD*cos(π/180*crs) - spd, y + 
        TGT_SPD*sin(π/180*crs)]
    crs = next_crs(crs,rng)
    r = sqrt(pos[1]^2 + pos[2]^2)
    θ = atan2(pos[1],pos[2])*180/π
    if θ < 0 θ += 360 end
    return (r, θ, crs, spd)::NTuple{4, Real}
end
#
# Out:
# f (generic function with 1 method)

# %%
function r(s)
    range = s[1]
    if range > 150 return -.1 end  # reward to not lose track of contact
    if range <= 10 return -1 end  # collision avoidance
    return .1  # being in "sweet spot" maximizes reward
end
#
# Out:
# r (generic function with 1 method)

# %%
#angles = [0, 30, 60, 90, 120, 150, 210, 240, 270, 300, 330]

statespace = thestates
actionspace = ((30,1), (0,1), (-30,1), (30, 2), (0,2), (-30,2))

action_index(a) = trunc(Int, 2*(a[1]/30+1) + a[2])
actions_ = ((-30,1), (-30, 2), (0, 1), (0, 2), (30, 1), (30, 2))
# Out:
# ((-30, 1), (-30, 2), (0, 1), (0, 2), (30, 1), (30, 2))

# %%
# returns vector rather than Tuple, for particle filter
function f2(x, u, rng)
    temp = [i for i in f(x, u, rng)]
    return temp
end
# Out:
# f2 (generic function with 1 method)

# %%
totals = [0.0]
θ = zeros(length(grid),6);
e = sparse(zeros(length(grid),6))
#θ = [r(Tuple(ind2x(grid, j))) for j in 1:length(grid), i in 1:6];

# %%
N = 500
model = ParticleFilterModel{Vector{Float64}}(f2, g)
pfilter = SIRParticleFilter(model, N);
α = 0.5
γ = 0.95
ϵ = 0.25
x = [20, 60, 90, 1, 1];
λ = 0.95
b = ParticleCollection([[20, 60, 90, 1] for i in 1:N]);
counter = 0
# Out:
# 0

# %%
## Q-learning loop
#plots = []
#betas = Deque{Array}()
#β = zeros(length(grid),6);

epochs = 1000
epochsize = 500

total = 0
rando = 0

last = 0
x = [rand(rng, 25:150), rand(rng,0:359), rand(rng,0:11)*30, 1, 1];     
b = ParticleCollection([x[1:4] for i in 1:N]);     
ξ = sparse(weighted_grid_2(b)/N)
uu = next_action([transpose(θ[:,j])*ξ for j in 1:size(θ)[2]], ϵ, rng)
u = uu[1]
rando += uu[2]

for i in 1:(epochsize*epochs)
    counter += 1
    
    e[:,u] += ξ
    
    # choose next action
    uu = next_action([transpose(θ[:,j])*ξ for j in 1:size(θ)[2]], ϵ, rng)
    u = uu[1]
    rando += uu[2]
    a_star = uu[3]
    
    #observe new state and reward
    xp = f2(x, actions_[u], rng)
    y = h(xp, rng)
    b = update(pfilter, b, actions_[u], y)
    rew = r(Tuple(xp))
       
    ξ = sparse(weighted_grid_2(b)/N)
     
    total += rew
        
    #cur = (rew + γ * max2([transpose(θ[:,j])*ξ for j in 1:size(θ)[2]], rng))
    
    #argmax state-action pair, not realized state-action pair?
    cur = transpose(θ[:,a_star])*ξ
    
    δ = rew + γ * cur - last
    last = cur
    
    θ += α * δ * e
    if uu[2] == 0
        e *= γ * λ
    else
        e = sparse(zeros(length(grid),6))
    end
    
        
    if counter % epochsize == 0
        push!(totals, total*500/epochsize)
        println("--------- CURRENT: ", round(total*500/epochsize, sigdigits=4), " AVG: ", round(mean(totals), sigdigits=4), " Epoch: ", 
            trunc(Int, counter/epochsize), " -----------")
        total = 0
        rando = 0
        xp = [rand(rng, 25:150), rand(rng,0:359), rand(rng,0:11)*30, rand(rng, [1,2]), 1];
        b = ParticleCollection([xp[1:4] for i in 1:N]);
        ξ = sparse(weighted_grid_2(b)/N)
    end
    if counter % (epochsize*5) == 0
        thetaframe = DataFrame(θ)
        CSV.write("current4.csv", thetaframe)
    end
    
    x = xp
    
    
    #plotting
    #r_ = [row[1] for row in particles(b)]
    #theta = [row[2] for row in particles(b)]*π/180
    #x_theta = x[2]*π/180
    #x_r = x[1 ]
    
    #print(".")
    #plt = plot(proj=:polar, lims=(0,200), size=(1000,1000))
    #scatter!(theta, r_, markersize=1, label="particles")
    #scatter!([x_theta], [x_r], markersize=3, label="target")
          
    #push!(plots, plt)
    
end
# Out:
# --------- CURRENT: 4.8 AVG: 2.4 Epoch: 1 -----------
# --------- CURRENT: -5.2 AVG: -0.1333 Epoch: 2 -----------
# --------- CURRENT: -30.3 AVG: -7.675 Epoch: 3 -----------
# --------- CURRENT: 23.6 AVG: -1.42 Epoch: 4 -----------
# --------- CURRENT: 50.0 AVG: 7.15 Epoch: 5 -----------
# --------- CURRENT: -12.0 AVG: 4.414 Epoch: 6 -----------
# --------- CURRENT: -43.2 AVG: -1.537 Epoch: 7 -----------
# --------- CURRENT: -7.4 AVG: -2.189 Epoch: 8 -----------
# --------- CURRENT: -31.8 AVG: -5.15 Epoch: 9 -----------
# --------- CURRENT: 27.8 AVG: -2.155 Epoch: 10 -----------
# --------- CURRENT: -43.8 AVG: -5.625 Epoch: 11 -----------
# --------- CURRENT: -48.0 AVG: -8.885 Epoch: 12 -----------
# --------- CURRENT: -36.6 AVG: -10.86 Epoch: 13 -----------
# --------- CURRENT: -47.6 AVG: -13.31 Epoch: 14 -----------
# --------- CURRENT: 22.0 AVG: -11.11 Epoch: 15 -----------
# --------- CURRENT: -34.0 AVG: -12.45 Epoch: 16 -----------
# --------- CURRENT: -43.4 AVG: -14.17 Epoch: 17 -----------
# --------- CURRENT: -42.8 AVG: -15.68 Epoch: 18 -----------
# --------- CURRENT: 0.2 AVG: -14.89 Epoch: 19 -----------
# --------- CURRENT: 34.0 AVG: -12.56 Epoch: 20 -----------
# --------- CURRENT: -26.6 AVG: -13.2 Epoch: 21 -----------
# --------- CURRENT: 50.0 AVG: -10.45 Epoch: 22 -----------
# --------- CURRENT: 50.0 AVG: -7.929 Epoch: 23 -----------
# --------- CURRENT: -17.4 AVG: -8.308 Epoch: 24 -----------
# --------- CURRENT: -33.2 AVG: -9.265 Epoch: 25 -----------
# --------- CURRENT: -30.2 AVG: -10.04 Epoch: 26 -----------
# --------- CURRENT: -40.6 AVG: -11.13 Epoch: 27 -----------
# --------- CURRENT: -18.0 AVG: -11.37 Epoch: 28 -----------
# --------- CURRENT: -32.4 AVG: -12.07 Epoch: 29 -----------
# --------- CURRENT: 16.1 AVG: -11.16 Epoch: 30 -----------
# --------- CURRENT: -17.6 AVG: -11.36 Epoch: 31 -----------
# --------- CURRENT: 38.2 AVG: -9.861 Epoch: 32 -----------
# --------- CURRENT: -40.0 AVG: -10.75 Epoch: 33 -----------
# --------- CURRENT: 10.5 AVG: -10.14 Epoch: 34 -----------
# --------- CURRENT: -34.2 AVG: -10.81 Epoch: 35 -----------
# --------- CURRENT: -23.6 AVG: -11.15 Epoch: 36 -----------
# --------- CURRENT: -24.8 AVG: -11.51 Epoch: 37 -----------
# --------- CURRENT: -38.0 AVG: -12.19 Epoch: 38 -----------
# --------- CURRENT: -17.4 AVG: -12.32 Epoch: 39 -----------
# --------- CURRENT: -43.0 AVG: -13.07 Epoch: 40 -----------
# --------- CURRENT: -22.8 AVG: -13.3 Epoch: 41 -----------
# --------- CURRENT: -31.2 AVG: -13.72 Epoch: 42 -----------
# --------- CURRENT: -29.8 AVG: -14.08 Epoch: 43 -----------
# --------- CURRENT: -41.2 AVG: -14.69 Epoch: 44 -----------
# --------- CURRENT: 8.1 AVG: -14.19 Epoch: 45 -----------
# --------- CURRENT: -19.6 AVG: -14.31 Epoch: 46 -----------
# --------- CURRENT: -27.2 AVG: -14.58 Epoch: 47 -----------
# --------- CURRENT: -30.0 AVG: -14.89 Epoch: 48 -----------
# --------- CURRENT: -46.4 AVG: -15.52 Epoch: 49 -----------
# --------- CURRENT: -41.0 AVG: -16.02 Epoch: 50 -----------
# --------- CURRENT: -15.4 AVG: -16.01 Epoch: 51 -----------
# --------- CURRENT: 1.6 AVG: -15.68 Epoch: 52 -----------
# --------- CURRENT: -10.6 AVG: -15.58 Epoch: 53 -----------
# --------- CURRENT: -46.8 AVG: -16.15 Epoch: 54 -----------
# --------- CURRENT: -21.2 AVG: -16.24 Epoch: 55 -----------
# --------- CURRENT: -42.6 AVG: -16.7 Epoch: 56 -----------
# --------- CURRENT: -30.2 AVG: -16.93 Epoch: 57 -----------
# --------- CURRENT: 8.2 AVG: -16.51 Epoch: 58 -----------
# --------- CURRENT: -37.0 AVG: -16.85 Epoch: 59 -----------
# --------- CURRENT: -42.0 AVG: -17.26 Epoch: 60 -----------
# --------- CURRENT: -34.2 AVG: -17.54 Epoch: 61 -----------
# --------- CURRENT: -28.6 AVG: -17.71 Epoch: 62 -----------
# --------- CURRENT: -5.2 AVG: -17.52 Epoch: 63 -----------
# --------- CURRENT: -47.2 AVG: -17.97 Epoch: 64 -----------
# --------- CURRENT:

# %%
transpose(θ[:,2])*ξ
# Out:
# 0.0015269765963268022

# %%
xx = []
yy = []
yyy = []
for (i, t) in enumerate(totals)
    push!(xx, i)
    push!(yy, t)
    push!(yyy, mean(yy))
end

plot(xx, yyy, ylims = (0,50))

# %%
# Out:
# 2.0131182926706272e35

# %%
thetaframe = DataFrame(θ)
CSV.write("0.44_theta_11.28_1", thetaframe)
# Out:
# "0.44_theta_11.28_1"

# %%
b = ParticleCollection([[20, 60, 90, 1] for i in 1:N]);
ξ = weighted_grid_2(b)/N
var(ξ)
# Out:
# 3.5612535612535624e-5
