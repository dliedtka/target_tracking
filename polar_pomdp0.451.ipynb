# %%
using Plots
using ParticleFilters
using Distributions
using StaticArrays
using LinearAlgebra
using Random
using StatsBase
#using Reel
using SparseArrays
using GridInterpolations
using DataStructures
using DataFrames
using CSV
using Distributed

# %%
include("atan2.jl")
include("obs_rel.jl")
include("polargrid_rel_qual.jl")
rng = MersenneTwister(2);
#

# %%
# random walk

POS_0 = [6.0, 60.0]
CRS_0 = 90 # target's course
SPD_0 = 1 # 1 or 2
TGT_SPD = 1

#input is course in degrees and rng
#returns next course in degrees
function next_crs(crs,rng)
    if rand(rng) < .9
        return crs
    end
    crs = (crs + rand(rng,[-1,1])*30) % 360
    if crs < 0 crs += 360 end
    return crs
end

# state as tuple (x, y, crs, spd) of target (spd of o/s)
function f(state, control, rng)
    r, θ, crs, spd = state
    θ += control[1]
    spd = control[2]
    if θ < 0 θ += 360 end
    θ = θ % 360
    crs -= control[1]
    if crs < 0 crs += 360 end
    crs = crs % 360
    x = r*cos(π/180*θ)
    y = r*sin(π/180*θ)
    pos = [x + TGT_SPD*cos(π/180*crs) - spd, y + 
        TGT_SPD*sin(π/180*crs)]
    crs = next_crs(crs,rng)
    r = sqrt(pos[1]^2 + pos[2]^2)
    θ = atan2(pos[1],pos[2])*180/π
    if θ < 0 θ += 360 end
    return (r, θ, crs, spd)::NTuple{4, Real}
end
#
# Out:
# f (generic function with 1 method)

# %%
function r(s)
    range = s[1]
    if range > 150 return -.1 end  # reward to not lose track of contact
    if range <= 10 return -1 end  # collision avoidance
    return .1  # being in "sweet spot" maximizes reward
end
#
# Out:
# r (generic function with 1 method)

# %%
#angles = [0, 30, 60, 90, 120, 150, 210, 240, 270, 300, 330]

statespace = thestates
actionspace = ((30,1), (0,1), (-30,1), (30, 2), (0,2), (-30,2))

action_index(a) = trunc(Int, 2*(a[1]/30+1) + a[2])
actions_ = ((-30,1), (-30, 2), (0, 1), (0, 2), (30, 1), (30, 2))
# Out:
# ((-30, 1), (-30, 2), (0, 1), (0, 2), (30, 1), (30, 2))

# %%
# returns vector rather than Tuple, for particle filter
function f2(x, u, rng)
    temp = [i for i in f(x, u, rng)]
    return temp
end
# Out:
# f2 (generic function with 1 method)

# %%
totals = [0.0]
θ = zeros(length(grid),6);
e = sparse(zeros(length(grid),6))
#θ = [r(Tuple(ind2x(grid, j))) for j in 1:length(grid), i in 1:6];

# %%
N = 500
model = ParticleFilterModel{Vector{Float64}}(f2, g)
pfilter = SIRParticleFilter(model, N);
α = 0.5
γ = 0.98
ϵ = 0.25
x = [20, 60, 90, 1, 1];
λ = 0.95
b = ParticleCollection([[20, 60, 90, 1] for i in 1:N]);
counter = 0
# Out:
# 0

# %%
## Q-learning loop
#plots = []
#betas = Deque{Array}()
#β = zeros(length(grid),6);

epochs = 5000
epochsize = 500

total = 0
rando = 0

last = 0
x = [rand(rng, 25:150), rand(rng,0:359), rand(rng,0:11)*30, 1, 1];     
b = ParticleCollection([x[1:4] for i in 1:N]);     
ξ = sparse(weighted_grid_2(b)/N)
uu = next_action([transpose(θ[:,j])*ξ for j in 1:size(θ)[2]], ϵ, rng)
u = uu[1]
rando += uu[2]

for i in 1:(epochsize*epochs)
    counter += 1
    
    e[:,u] += ξ
    last = transpose(θ[:,u])*ξ
    
    # choose next action
    uu = next_action([transpose(θ[:,j])*ξ for j in 1:size(θ)[2]], ϵ, rng)
    u = uu[1]
    rando += uu[2]
    a_star = uu[3]
    
    #observe new state and reward
    xp = f2(x, actions_[u], rng)
    y = h(xp, rng)
    b = update(pfilter, b, actions_[u], y)
    rew = r(Tuple(xp))
       
    ξ = sparse(weighted_grid_2(b)/N)
     
    total += rew
        
    #cur = (rew + γ * max2([transpose(θ[:,j])*ξ for j in 1:size(θ)[2]], rng))
    
    #argmax state-action pair, not realized state-action pair?
    cur = transpose(θ[:,a_star])*ξ
    
    δ = rew + γ * cur - last
    
    θ += α * δ * e
    if uu[2] == 0
        e *= γ * λ
    else
        e = sparse(zeros(length(grid),6))
    end
    
        
    if counter % epochsize == 0
        push!(totals, total*500/epochsize)
        println("--------- CURRENT: ", round(total*500/epochsize, sigdigits=4), " AVG: ", round(mean(totals), sigdigits=4), " Epoch: ", 
            trunc(Int, counter/epochsize), " -----------")
        total = 0
        rando = 0
        xp = [rand(rng, 25:150), rand(rng,0:359), rand(rng,0:11)*30, rand(rng, [1,2]), 1];
        b = ParticleCollection([xp[1:4] for i in 1:N]);
        ξ = sparse(weighted_grid_2(b)/N)
    end
    if counter % (epochsize*5) == 0
        thetaframe = DataFrame(θ)
        CSV.write("current4_1.csv", thetaframe)
    end
    
    x = xp
    
    
    #plotting
    #r_ = [row[1] for row in particles(b)]
    #theta = [row[2] for row in particles(b)]*π/180
    #x_theta = x[2]*π/180
    #x_r = x[1 ]
    
    #print(".")
    #plt = plot(proj=:polar, lims=(0,200), size=(1000,1000))
    #scatter!(theta, r_, markersize=1, label="particles")
    #scatter!([x_theta], [x_r], markersize=3, label="target")
          
    #push!(plots, plt)
    
end
# Out:
# --------- CURRENT: 9.0 AVG: 7.158 Epoch: 13223 -----------
# --------- CURRENT: -0.8 AVG: 7.157 Epoch: 13224 -----------
# --------- CURRENT: 33.6 AVG: 7.159 Epoch: 13225 -----------
# --------- CURRENT: 26.9 AVG: 7.161 Epoch: 13226 -----------
# --------- CURRENT: -21.8 AVG: 7.159 Epoch: 13227 -----------
# --------- CURRENT: -49.2 AVG: 7.154 Epoch: 13228 -----------
# --------- CURRENT: 5.7 AVG: 7.154 Epoch: 13229 -----------
# --------- CURRENT: -8.2 AVG: 7.153 Epoch: 13230 -----------
# --------- CURRENT: -11.0 AVG: 7.152 Epoch: 13231 -----------
# --------- CURRENT: 7.8 AVG: 7.152 Epoch: 13232 -----------
# --------- CURRENT: 32.4 AVG: 7.154 Epoch: 13233 -----------
# --------- CURRENT: 37.9 AVG: 7.156 Epoch: 13234 -----------
# --------- CURRENT: -31.2 AVG: 7.153 Epoch: 13235 -----------
# --------- CURRENT: -6.0 AVG: 7.152 Epoch: 13236 -----------
# --------- CURRENT: 4.4 AVG: 7.152 Epoch: 13237 -----------
# --------- CURRENT: 50.0 AVG: 7.155 Epoch: 13238 -----------
# --------- CURRENT: 7.6 AVG: 7.155 Epoch: 13239 -----------
# --------- CURRENT: 28.0 AVG: 7.157 Epoch: 13240 -----------
# --------- CURRENT: 45.2 AVG: 7.16 Epoch: 13241 -----------
# --------- CURRENT: 50.0 AVG: 7.163 Epoch: 13242 -----------
# --------- CURRENT: 50.0 AVG: 7.166 Epoch: 13243 -----------
# --------- CURRENT: 30.2 AVG: 7.168 Epoch: 13244 -----------
# --------- CURRENT: -26.2 AVG: 7.165 Epoch: 13245 -----------
# --------- CURRENT: -42.4 AVG: 7.161 Epoch: 13246 -----------
# --------- CURRENT: 19.2 AVG: 7.162 Epoch: 13247 -----------
# --------- CURRENT: 15.6 AVG: 7.163 Epoch: 13248 -----------
# --------- CURRENT: -18.4 AVG: 7.161 Epoch: 13249 -----------
# --------- CURRENT: 41.4 AVG: 7.164 Epoch: 13250 -----------
# --------- CURRENT: 42.8 AVG: 7.166 Epoch: 13251 -----------
# --------- CURRENT: 6.2 AVG: 7.166 Epoch: 13252 -----------
# --------- CURRENT: -27.6 AVG: 7.164 Epoch: 13253 -----------
# --------- CURRENT: 17.1 AVG: 7.164 Epoch: 13254 -----------
# --------- CURRENT: 50.0 AVG: 7.168 Epoch: 13255 -----------
# --------- CURRENT: 18.8 AVG: 7.168 Epoch: 13256 -----------
# --------- CURRENT: 42.3 AVG: 7.171 Epoch: 13257 -----------
# --------- CURRENT: -48.0 AVG: 7.167 Epoch: 13258 -----------
# --------- CURRENT: 42.3 AVG: 7.17 Epoch: 13259 -----------
# --------- CURRENT: 26.6 AVG: 7.171 Epoch: 13260 -----------
# --------- CURRENT: -31.2 AVG: 7.168 Epoch: 13261 -----------
# --------- CURRENT: -26.0 AVG: 7.166 Epoch: 13262 -----------
# --------- CURRENT: 36.8 AVG: 7.168 Epoch: 13263 -----------
# --------- CURRENT: 50.0 AVG: 7.171 Epoch: 13264 -----------
# --------- CURRENT: 21.0 AVG: 7.172 Epoch: 13265 -----------
# --------- CURRENT: -33.4 AVG: 7.169 Epoch: 13266 -----------
# --------- CURRENT: -35.6 AVG: 7.166 Epoch: 13267 -----------
# --------- CURRENT: 43.8 AVG: 7.169 Epoch: 13268 -----------
# --------- CURRENT: -22.2 AVG: 7.166 Epoch: 13269 -----------
# --------- CURRENT: -37.0 AVG: 7.163 Epoch: 13270 -----------
# --------- CURRENT: -32.6 AVG: 7.16 Epoch: 13271 -----------
# --------- CURRENT: -33.4 AVG: 7.157 Epoch: 13272 -----------
# --------- CURRENT: 33.5 AVG: 7.159 Epoch: 13273 -----------
# --------- CURRENT: -16.8 AVG: 7.157 Epoch: 13274 -----------
# --------- CURRENT: -10.2 AVG: 7.156 Epoch: 13275 -----------
# --------- CURRENT: -15.8 AVG: 7.154 Epoch: 13276 -----------
# --------- CURRENT: 32.0 AVG: 7.156 Epoch: 13277 -----------
# --------- CURRENT: -12.2 AVG: 7.155 Epoch: 13278 -----------
# --------- CURRENT: 10.4 AVG: 7.155 Epoch: 13279 -----------
# --------- CURRENT: 36.2 AVG: 7.157 Epoch: 13280 -----------
# --------- CURRENT: 14.4 AVG: 7.158 Epoch: 13281 -----------

# %%
transpose(θ[:,2])*ξ
# Out:
# 0.0015269765963268022

# %%
xx = []
yy = []
yyy = []
for (i, t) in enumerate(totals)
    push!(xx, i)
    push!(yy, t)
    push!(yyy, mean(yy))
end

plot(xx, yyy, ylims = (0,50))

# %%
# Out:
# 2.0131182926706272e35

# %%
thetaframe = DataFrame(θ)
CSV.write("0.44_theta_11.28_1", thetaframe)
# Out:
# "0.44_theta_11.28_1"

# %%
b = ParticleCollection([[20, 60, 90, 1] for i in 1:N]);
ξ = weighted_grid_2(b)/N
var(ξ)
# Out:
# 3.5612535612535624e-5
