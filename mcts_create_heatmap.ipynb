# %%
import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

# %%
plt.show()
heatmap_data = np.loadtxt("mcts_heatmap/sample_depth5_heatmap.csv", delimiter=',')
ax = sns.heatmap(heatmap_data)

# %%
plt.show()
heatmap_data = np.loadtxt("mcts_heatmap/sample_depth1_heatmap.csv", delimiter=',') # modified reward
ax = sns.heatmap(heatmap_data)

# %%
plt.show()
heatmap_data = np.loadtxt("mcts_heatmap/sample_depth10_heatmap.csv", delimiter=',') # modified reward
ax = sns.heatmap(heatmap_data)

# %%
plt.show()
heatmap_data = np.loadtxt("mcts_heatmap/sample_depth25_heatmap.csv", delimiter=',') # not modified reward
ax = sns.heatmap(heatmap_data)
